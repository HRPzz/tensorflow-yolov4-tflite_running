# %% [markdown]
# # 🏄‍♀️YOLO 4 깃허브 클론 하기
#
# - 참고 블로그 : https://wiserloner.tistory.com/1187
# - 참고 유튜브 : https://youtu.be/iPwepy-SVCQ
#
# <br>
#
# 위의 블로그와 유튜브 영상을 따라하면서, 이미지와 비디오에서 target detection을 연습해 봄!

# %% [markdown]
# ## 1. 깃허브를 코랩으로 클론하기

# %% [markdown]
# - `!git clone 깃허브 주소` : 코랩으로 깃허브를 클론할 수 있다.

# %%
# !git clone https://github.com/Seona056/tensorflow-yolov4-tflite.git

# %% [markdown]
# - `os.chdir('디렉토리')`  : 현재 위치 디렉토리를 변경

# %%
import os
os.chdir('tensorflow-yolov4-tflite')

# %% [markdown]
# - `pwd` : 현재 폴더 경로 출력
# - `ls` : 현재 폴더 내용물 출력
# - `cd <폴더명>` : 다른 폴더로 이동
# - `cd ..` : 상위 폴더로 이동
# - `cp` : 파일을 다른 이름으로 복사
# - `rm` : 파일을 삭제

# %%
# !ls
# Out:
# CODE_OF_CONDUCT.md  conda-cpu.yml      detect.py	     requirements.txt
# LICENSE		    conda-gpu.yml      detect_video.py	     save_model.py
# README.md	    convert_tflite.py  detections	     scripts
# android		    convert_trt.py     evaluate.py	     train.py
# benchmarks.py	    core	       mAP
# checkpoints	    data	       requirements-gpu.txt

# %% [markdown]
# ## 2. YOLOv4 Using Tensorflow (tf, .pb model)
#
# <br>
#
# >❗ 아래 명령어들을 실행하기 전에, `yolo4.weights`를 다운받아서 `data` 폴더에 업로드 시켜야합니다!<br><br>
# 👉 https://drive.google.com/file/d/1cewMfusmPjYWbrnuJRuKhPMwRe_b9PaT/view
#
# <br>
#
# To implement YOLOv4 using TensorFlow, first we convert the .weights into the corresponding TensorFlow model files and then run the model.

# %% [markdown]
# ### 2-1) 학습된 가중치 모델 불러오기

# %% [markdown]
# - 인자값에 따라서 아주 쉽게 텐서플로 모델을 만들수 있으며, **`weights`**는 위에서 준비한 것을 사용하고, **`output`**으로 해당 경로에 출력파일이 저장된다.

# %%
# Convert darknet weights to tensorflow
## yolov4
# !python save_model.py --weights ./data/yolov4.weights --output ./checkpoints/yolov4-416 --input_size 416 --model yolov4
# Out:
# 2022-05-08 09:31:21.850256: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory
# 2022-05-08 09:31:21.850297: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-05-08 09:31:24.132671: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2022-05-08 09:31:24.736719: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-05-08 09:31:24.737340: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla V100-SXM2-16GB computeCapability: 7.0
# ...

# %% [markdown]
# ### 2-2) image detection
#
# <br>
#
# - `./data/images/`에 **dog.jpg, kite.jpg** 두 개의 파일이 들어있다.
# - 깃허브 리드미에 있는 명령어를 그대로 실행하면 결과 png파일이 `./data/detections/`에 파일명이 **detection{i}**인 png파일로 저장된다.
# - 명령어 끝에 `--output ./detections/파일명_`을 입력하면, **입력한 파일명_detection1**으로 저장된다.

# %%
# Run yolov4 tensorflow model
# !python detect.py --weights ./checkpoints/yolov4-416 --size 416 --model yolov4 --images ./data/images/kite.jpg --output ./detections/kite_
# Out:
# 2022-05-08 08:22:37.872284: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory
# 2022-05-08 08:22:37.872347: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-05-08 08:22:38.878234: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2022-05-08 08:22:38.881180: E tensorflow/stream_executor/cuda/cuda_driver.cc:314] failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2022-05-08 08:22:38.881226: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aiffel-dg1-1
# 2022-05-08 08:22:38.881235: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aiffel-dg1-1
# ...

# %%
# Run yolov4 tensorflow model
# !python detect.py --weights ./checkpoints/yolov4-416 --size 416 --model yolov4 --images ./data/images/dog.jpg --output ./detections/dog_
# Out:
# 2022-05-08 08:23:30.594126: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory
# 2022-05-08 08:23:30.594178: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-05-08 08:23:31.592111: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2022-05-08 08:23:31.594957: E tensorflow/stream_executor/cuda/cuda_driver.cc:314] failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2022-05-08 08:23:31.595009: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aiffel-dg1-1
# 2022-05-08 08:23:31.595028: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aiffel-dg1-1
# ...

# %% [markdown]
# - 2개의 파일을 동시에 넣을 수도 있다.

# %%
# !python detect.py --weights ./checkpoints/yolov4-416 --size 416 --model yolov4 --images "./data/images/kite.jpg, ./data/images/dog.jpg"
# Out:
# 2022-05-08 08:24:29.309643: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory
# 2022-05-08 08:24:29.309692: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-05-08 08:24:30.298880: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2022-05-08 08:24:30.301803: E tensorflow/stream_executor/cuda/cuda_driver.cc:314] failed call to cuInit: CUDA_ERROR_UNKNOWN: unknown error
# 2022-05-08 08:24:30.301865: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aiffel-dg1-1
# 2022-05-08 08:24:30.301885: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aiffel-dg1-1
# ...

# %% [markdown]
# 위의 코드를 실행하면 **detection1.png, detection2.png**로 저장됨 (같은 파일명이 있다면 덮어쓰기 된다.)
#
# <br>
#
# > 🤢 왜인지 `dog.jpg`는 제대로 detection이 되지 않는다.<Br>
# 1장만 입력했을 때는 잘 되었음

# %% [markdown]
# ### 2-3) video detection
#
# <br>
#
# 기본적으로 이미지와 사용하는 방법이 같다.

# %%
# Run yolov4 on video
# !python detect_video.py --weights ./checkpoints/yolov4-416 --size 416 --model yolov4 --video ./data/video/video.mp4 --output ./detections/results.avi
# Out:
# 2022-05-08 09:43:40.349361: W tensorflow/stream_executor/platform/default/dso_loader.cc:59] Could not load dynamic library 'libcudart.so.10.1'; dlerror: libcudart.so.10.1: cannot open shared object file: No such file or directory
# 2022-05-08 09:43:40.349432: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-05-08 09:43:41.241557: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2022-05-08 09:43:42.103013: E tensorflow/stream_executor/cuda/cuda_driver.cc:314] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-05-08 09:43:42.103083: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: aiffel-dg1-1
# 2022-05-08 09:43:42.103100: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: aiffel-dg1-1
# ...

# %% [markdown]
# >❌에러❌<br>
# `cannot connect to X server` <br>
# - x window 시스템에서만 작동한다고 함. (로컬 환경)
# - 코랩에서 사용하기 위해서는, `detect_video.py`에서
#
# ```
# #cv2.namedWindow("motion")
# #cv2.imshow("motion", img)# モーション画像を表示
# #cv2.destroyAllWindows()
# ```
# 를 주석처리 하거나,
# ```
# import os
# os.environ["CUDA_VISIBLE_DEVICES"] = "1"
# ```
# 코드를 입력한다.
#
# <br>
#
# 👉 <u>근데 안됨</u>
#
# - https://stackoverflow.com/questions/54577083/cannot-connect-to-x-server-google-colab

# %% [markdown]
# ### 2-4) 웹캠에서 실행하기

# %%
# Run yolov4 on webcam
# !python detect_video.py --weights ./checkpoints/yolov4-416 --size 416 --model yolov4 --video 0 --output ./detections/results.avi
